# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
start = np.loadtxt("./start.txt")
end = np.loadtxt("./end.txt")
final = np.loadtxt("./final.txt")

# %%
plt.scatter(x=start[:, 0], y=start[:, 1])
plt.scatter(x=end[:, 0], y=end[:, 1])
plt.scatter(x=final[:, 0], y=final[:, 1])
plt.gca().set_aspect("equal")
